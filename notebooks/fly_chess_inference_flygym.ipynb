# %% [markdown]
# # Fly chess inference with FlyGym

# %%
# !git clone -q https://github.com/mncrftfrcnm/making-fly-play-chess.git /content/making-fly-play-chess
# %cd /content/making-fly-play-chess

# %%
# !pip install -q -r requirements-flygym.txt

# %%
import os
os.environ.setdefault("MUJOCO_GL", "egl")
os.environ.setdefault("PYOPENGL_PLATFORM", "egl")

# %run scripts/fly_chess_inference_flygym.py
